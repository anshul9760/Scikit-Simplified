# %% [markdown]
# # Polynoial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn
seaborn.set()

# %% [markdown]
# # Exemplary Dataset

# %%
X_train = [[6],[8],[10],[14],[18]]
y_train = [[7],[9],[13],[17.5],[18]]
X_test = [[6],[8],[11],[16]]
y_test = [[8],[12],[15],[18]]

# %%
regg=LinearRegression()
regg.fit(X_train, y_train)
plt.scatter(X_train, y_train)

# %% [markdown]
# # Plotting Linearly

# %%
plt.scatter(X_train, y_train)
xx = np.linspace(0, 26, 100)
yy = regg.predict(xx.reshape(xx.shape[0], 1))
plt.plot(xx, yy)

# %% [markdown]
# # Plotting via Polynomial Regression

# %%
qf = PolynomialFeatures(degree=2)
Xtrqf = qf.fit_transform(X_train)
Xtsqf = qf.transform(X_test)
reggq=LinearRegression()
reggq.fit(Xtrqf, y_train)
xxqf = qf.transform(xx.reshape(xx.shape[0], 1))

# %%
plt.scatter(X_train, y_train)
plt.plot(xx, yy)
plt.plot(xx, reggq.predict(xxqf), c='r', linestyle = '--')
